# %% [markdown]
# <a href="https://colab.research.google.com/github/Nivedha1524/NLP/blob/main/2403A52279_ASS_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **CORPUS**

# %%
D1:"I Like machine learning"
D2:"I Like deep learning"
D3:"I Like playing Badminton"
D4:"I Like playing cricket"
D5: "I am studying B.Tech at SR University."
D6:" I am learning NLP during my B.Tech course."
D7: "I completed my intermediate education in MPC"
D8: "I want to become a software engineer."
D9:" I Like watching movies"
D10:"I am a good girl"

# %% [markdown]
# **UNIGRAM COUNTS**

# %%
import collections
D1:"I Like machine learning"
D2:"I Like deep learning"
D3:"I Like playing Badminton"
D4:"I Like playing cricket"
D5: "I am studying B.Tech at SR University."
D6:" I am learning NLP during my B.Tech course."
D7: "I completed my intermediate education in MPC"
D8: "I want to become a software engineer."
D9:" I Like watching movies"
D10:"I am a good girl"

D1_content = "I Like machine learning"
D2_content = "I Like deep learning"
D3_content = "I Like playing Badminton"
D4_content = "I Like playing cricket"
D5_content = "I am studying B.Tech at SR University."
D6_content = "I am learning NLP during my B.Tech course."
D7_content = "I completed my intermediate education in MPC"
D8_content = "I want to become a software engineer."
D9_content = "I Like watching movies"
D10_content = "I am a good girl"
combined_text = f"{D1_content} {D2_content} {D3_content} {D4_content} {D5_content} {D6_content} {D7_content} {D8_content} {D9_content} {D10_content}"
words = combined_text.lower().split()
unigram_counts = collections.Counter(words)
print("Unigram Counts:")
for word, count in unigram_counts.most_common():
    print(f"{word}: {count}")
V=len(unigram_counts)
print("Vocabulary Size=",V)
# Out:
# Unigram Counts:
# i: 10
# like: 5
# learning: 3
# am: 3
# playing: 2
# b.tech: 2
# my: 2
# a: 2
# machine: 1
# deep: 1
# badminton: 1
# cricket: 1
# studying: 1
# at: 1
# sr: 1
# university.: 1
# nlp: 1
# during: 1
# course.: 1
# completed: 1
# intermediate: 1
# education: 1
# in: 1
# mpc: 1
# want: 1
# to: 1
# become: 1
# software: 1
# engineer.: 1
# watching: 1
# movies: 1
# good: 1
# girl: 1
# Vocabulary Size= 33

# %% [markdown]
# **BIGRAM COUNTS**

# %%
import collections
combined_text = f"{D1_content} {D2_content} {D3_content} {D4_content} {D5_content} {D6_content} {D7_content} {D8_content} {D9_content} {D10_content}"
words = combined_text.lower().split()
bigrams = []
for i in range(len(words) - 1):
    bigrams.append((words[i], words[i+1]))
bigram_counts = collections.Counter(bigrams)
print("\nBigram Counts:")
for bigram, count in bigram_counts.most_common():
    print(f"{bigram[0]} {bigram[1]}: {count}")
# Out:
# Bigram Counts:
# i like: 5
# i am: 3
# learning i: 2
# like playing: 2
# like machine: 1
# machine learning: 1
# like deep: 1
# deep learning: 1
# playing badminton: 1
# badminton i: 1
# playing cricket: 1
# cricket i: 1
# am studying: 1
# studying b.tech: 1
# b.tech at: 1
# at sr: 1
# sr university.: 1
# university. i: 1
# am learning: 1
# learning nlp: 1
# nlp during: 1
# during my: 1
# my b.tech: 1
# b.tech course.: 1
# course. i: 1
# i completed: 1
# completed my: 1
# my intermediate: 1
# intermediate education: 1
# education in: 1
# in mpc: 1
# mpc i: 1
# i want: 1
# want to: 1
# to become: 1
# become a: 1
# a software: 1
# software engineer.: 1
# engineer. i: 1
# like watching: 1
# watching movies: 1
# movies i: 1
# am a: 1
# a good: 1
# good girl: 1

# %% [markdown]
# **TRIGRAM COUNTS**

# %%
import collections
combined_text = f"{D1_content} {D2_content} {D3_content} {D4_content} {D5_content} {D6_content} {D7_content} {D8_content} {D9_content} {D10_content}"
words = combined_text.lower().split()
Trigrams = []
for i in range(len(words) - 2):
    Trigrams.append((words[i], words[i+1], words[i+2]))
Trigrams_counts = collections.Counter(Trigrams)
print("\nTrigrams Counts:")
for Trigrams, count in Trigrams_counts.most_common():
    print(f"{Trigrams[0]} {Trigrams[1]} {Trigrams[2]}: {count}")
# Out:
# Trigrams Counts:
# learning i like: 2
# i like playing: 2
# i like machine: 1
# like machine learning: 1
# machine learning i: 1
# i like deep: 1
# like deep learning: 1
# deep learning i: 1
# like playing badminton: 1
# playing badminton i: 1
# badminton i like: 1
# like playing cricket: 1
# playing cricket i: 1
# cricket i am: 1
# i am studying: 1
# am studying b.tech: 1
# studying b.tech at: 1
# b.tech at sr: 1
# at sr university.: 1
# sr university. i: 1
# university. i am: 1
# i am learning: 1
# am learning nlp: 1
# learning nlp during: 1
# nlp during my: 1
# during my b.tech: 1
# my b.tech course.: 1
# b.tech course. i: 1
# course. i completed: 1
# i completed my: 1
# completed my intermediate: 1
# my intermediate education: 1
# intermediate education in: 1
# education in mpc: 1
# in mpc i: 1
# mpc i want: 1
# i want to: 1
# want to become: 1
# to become a: 1
# become a software: 1
# a software engineer.: 1
# software engineer. i: 1
# engineer. i like: 1
# i like watching: 1
# like watching movies: 1
# watching movies i: 1
# movies i am: 1
# i am a: 1
# am a good: 1
# a good girl: 1

# %% [markdown]
# **NEXT WORD PREDICTION USING BIGRAM COUNTS**

# %%
def predict_next_word_bigram(word_sequence, bigram_counts, unigram_counts):
    words_in_sequence = word_sequence.lower().split()
    if not words_in_sequence:
        return "Please provide a word sequence."
    last_word = words_in_sequence[-1]

    potential_next_words = {}
    for (w1, w2), count in bigram_counts.items():
        if w1 == last_word:
            potential_next_words[w2] = count

    if not potential_next_words:
        return f"No bigram found starting with '{last_word}'."
    last_word_unigram_count = unigram_counts.get(last_word, 0)
    if last_word_unigram_count == 0:
        return f"'{last_word}' not found in unigram counts. Cannot predict next word."

    predicted_word = None
    max_probability = -1

    for next_word, bigram_count in potential_next_words.items():
        probability = bigram_count / last_word_unigram_count
        print("probability of  " f'{next_word}' " is ", probability)
        if probability > max_probability:
            max_probability = probability
            predicted_word = next_word

    return predicted_word

sequence1 = "I Like"
next_word1 = predict_next_word_bigram(sequence1, bigram_counts, unigram_counts)
print(f"Given sequence: '{sequence1}', predicted next word: '{next_word1}'")

sequence2 = "I am"
next_word2 = predict_next_word_bigram(sequence2, bigram_counts, unigram_counts)
print(f"Given sequence: '{sequence2}', predicted next word: '{next_word2}'")

sequence3 = "playing badminton"
next_word3 = predict_next_word_bigram(sequence3, bigram_counts, unigram_counts)
print(f"Given sequence: '{sequence3}', predicted next word: '{next_word3}'")

sequence4 = "learning i"
next_word4 = predict_next_word_bigram(sequence4, bigram_counts, unigram_counts)
print(f"Given sequence: '{sequence4}', predicted next word: '{next_word4}'")
# Out:
# probability of  machine is  0.2
# probability of  deep is  0.2
# probability of  playing is  0.4
# probability of  watching is  0.2
# Given sequence: 'I Like', predicted next word: 'playing'
# probability of  studying is  0.3333333333333333
# probability of  learning is  0.3333333333333333
# probability of  a is  0.3333333333333333
# Given sequence: 'I am', predicted next word: 'studying'
# probability of  i is  1.0
# Given sequence: 'playing badminton', predicted next word: 'i'
# probability of  like is  0.5
# probability of  am is  0.3
# probability of  completed is  0.1
# probability of  want is  0.1
# Given sequence: 'learning i', predicted next word: 'like'

# %% [markdown]
# **DEPLOYMENT OF BIGRAM MODEL**

# %%
ip_text=input("enter text")
next_word1 = predict_next_word_bigram(ip_text, bigram_counts, unigram_counts)
print(f"Given sequence: '{ip_text}', predicted next word: '{next_word1}'")
# Out:
# enter textplaying badminton
# probability of  i is  1.0
# Given sequence: 'playing badminton', predicted next word: 'i'

# %% [markdown]
# **NEXT WORD PREDICTION USING TRIGRAM COUNTS**

# %%
def predict_next_word_trigram(word_sequence, Trigrams_counts, bigram_counts):
    words_in_sequence = word_sequence.lower().split()
    if not words_in_sequence:
        return "Please provide a word sequence."
    if len(words_in_sequence) < 2:
        return "Sequence must contain at least two words for trigram prediction."
    last_two_words_tuple = tuple(words_in_sequence[-2:])
    potential_next_words = {}
    for (w1, w2, w3), count in Trigrams_counts.items():
        if (w1, w2) == last_two_words_tuple:
            potential_next_words[w3] = count

    if not potential_next_words:
        return f"No trigram found starting with '{' '.join(last_two_words_tuple)}'."

    last_two_words_bigram_count = bigram_counts.get(last_two_words_tuple, 0)
    if last_two_words_bigram_count == 0:
        return f"'{' '.join(last_two_words_tuple)}' not found as a bigram. Cannot predict next word."

    predicted_word = None
    max_probability = -1

    for next_word, trigram_count in potential_next_words.items():
        probability = trigram_count / last_two_words_bigram_count
        print("probability of  " f'{next_word}' " is ", probability)
        if probability > max_probability:
            max_probability = probability
            predicted_word = next_word

    return predicted_word

sequence1 = "learning i like"
next_word1 = predict_next_word_trigram(sequence1, Trigrams_counts, bigram_counts)
print(f"Given sequence: '{sequence1}', predicted next word: '{next_word1}'")

sequence2 = "am a good"
next_word2 = predict_next_word_trigram(sequence2, Trigrams_counts, bigram_counts)
print(f"Given sequence: '{sequence2}', predicted next word: '{next_word2}'")
# Out:
# probability of  machine is  0.2
# probability of  deep is  0.2
# probability of  playing is  0.4
# probability of  watching is  0.2
# Given sequence: 'learning i like', predicted next word: 'playing'
# probability of  girl is  1.0
# Given sequence: 'am a good', predicted next word: 'girl'

# %% [markdown]
# **DEPLOYMENT OF TRIGRAM MODEL**

# %%
ip_text=input("enter text")
next_word1 = predict_next_word_trigram(ip_text, Trigrams_counts, bigram_counts)
print(f"Given sequence: '{ip_text}', predicted next word: '{next_word1}'")
# Out:
# enter textlearning i like
# probability of  machine is  0.2
# probability of  deep is  0.2
# probability of  playing is  0.4
# probability of  watching is  0.2
# Given sequence: 'learning i like', predicted next word: 'playing'

# %% [markdown]
# **NEXT WORD PREDICTION USING BIGRAM COUNTS WITH LAPLACE SMOOTHENING**

# %%
def predict_next_word_bigram_Laplace(word_sequence, bigram_counts, unigram_counts):
    words_in_sequence = word_sequence.lower().split()
    if not words_in_sequence:
        return "Please provide a word sequence."
    last_word = words_in_sequence[-1]
    potential_next_words = {}
    for (w1, w2), count in bigram_counts.items():
        if w1 == last_word:
            potential_next_words[w2] = count

    if not potential_next_words:
        return f"No bigram found starting with '{last_word}'."
    last_word_unigram_count = unigram_counts.get(last_word, 0)
    if last_word_unigram_count == 0:
        return f"'{last_word}' not found in unigram counts. Cannot predict next word."

    predicted_word = None
    max_probability = -1

    for next_word, bigram_count in potential_next_words.items():
        probability = (bigram_count+1) / (last_word_unigram_count+V)
        print("probability of " f'{next_word}' " is ", probability)
        if probability > max_probability:
            max_probability = probability
            predicted_word = next_word

    return predicted_word

sequence1 = "I Like"
next_word1 = predict_next_word_bigram_Laplace(sequence1, bigram_counts, unigram_counts)
print(f"Given sequence: '{sequence1}', predicted next word: '{next_word1}'")

sequence2 = "I am"
next_word2 = predict_next_word_bigram_Laplace(sequence2, bigram_counts, unigram_counts)
print(f"Given sequence: '{sequence2}', predicted next word: '{next_word2}'")

sequence3 = "playing badminton"
next_word3 = predict_next_word_bigram_Laplace(sequence3, bigram_counts, unigram_counts)
print(f"Given sequence: '{sequence3}', predicted next word: '{next_word3}'")

sequence4 = "learning i"
next_word4 = predict_next_word_bigram_Laplace(sequence4, bigram_counts, unigram_counts)
print(f"Given sequence: '{sequence4}', predicted next word: '{next_word4}'")
# Out:
# probability of machine is  0.05263157894736842
# probability of deep is  0.05263157894736842
# probability of playing is  0.07894736842105263
# probability of watching is  0.05263157894736842
# Given sequence: 'I Like', predicted next word: 'playing'
# probability of studying is  0.05555555555555555
# probability of learning is  0.05555555555555555
# probability of a is  0.05555555555555555
# Given sequence: 'I am', predicted next word: 'studying'
# probability of i is  0.058823529411764705
# Given sequence: 'playing badminton', predicted next word: 'i'
# probability of like is  0.13953488372093023
# probability of am is  0.09302325581395349
# probability of completed is  0.046511627906976744
# probability of want is  0.046511627906976744
# Given sequence: 'learning i', predicted next word: 'like'

# %% [markdown]
# **DEPLOYMENT OF LAPLACE SMOOTHENING BASED BIGRAM MODEL**

# %%
ip_text=input("enter text")
next_word1 = predict_next_word_bigram_Laplace(ip_text, bigram_counts, unigram_counts)
print(f"Given sequence: '{ip_text}', predicted next word: '{next_word1}'")
# Out:
# enter textlearning i
# probability of like is  0.13953488372093023
# probability of am is  0.09302325581395349
# probability of completed is  0.046511627906976744
# probability of want is  0.046511627906976744
# Given sequence: 'learning i', predicted next word: 'like'

# %% [markdown]
# **NEXT WORD PREDICTION USING TRIGRAM COUNTS WITH LAPLACE SMOOTHENING**

# %%
def predict_next_word_trigram_Laplace(word_sequence, Trigrams_counts, bigram_counts):
    words_in_sequence = word_sequence.lower().split()
    if not words_in_sequence:
        return "Please provide a word sequence."
    if len(words_in_sequence) < 2:
        return "Sequence must contain at least two words for trigram prediction."

    last_two_words_tuple = tuple(words_in_sequence[-2:])
    potential_next_words = {}
    for (w1, w2, w3), count in Trigrams_counts.items():
        if (w1, w2) == last_two_words_tuple:
            potential_next_words[w3] = count

    if not potential_next_words:
        return f"No trigram found starting with '{' '.join(last_two_words_tuple)}'."

    last_two_words_bigram_count = bigram_counts.get(last_two_words_tuple, 0)
    if last_two_words_bigram_count == 0:
        return f"'{' '.join(last_two_words_tuple)}' not found as a bigram. Cannot predict next word."

    predicted_word = None
    max_probability = -1

    for next_word, trigram_count in potential_next_words.items():
        probability = (trigram_count+1) / (last_two_words_bigram_count+V)
        print("probability of  " f'{next_word}' " is ", probability)
        if probability > max_probability:
            max_probability = probability
            predicted_word = next_word

    return predicted_word

sequence1 = "learning i like"
next_word1 = predict_next_word_trigram_Laplace(sequence1, Trigrams_counts, bigram_counts)
print(f"Given sequence: '{sequence1}', predicted next word: '{next_word1}'")

sequence2 = "am a good"
next_word2 = predict_next_word_trigram_Laplace(sequence2, Trigrams_counts, bigram_counts)
print(f"Given sequence: '{sequence2}', predicted next word: '{next_word2}'")
# Out:
# probability of  machine is  0.05263157894736842
# probability of  deep is  0.05263157894736842
# probability of  playing is  0.07894736842105263
# probability of  watching is  0.05263157894736842
# Given sequence: 'learning i like', predicted next word: 'playing'
# probability of  girl is  0.058823529411764705
# Given sequence: 'am a good', predicted next word: 'girl'

# %% [markdown]
# **DEPLOYMENT OF LAPLACE SMOOTHENING BASED TRIGRAM MODEL**

# %%
ip_text=input("enter text")
next_word1 = predict_next_word_trigram_Laplace(ip_text, Trigrams_counts, bigram_counts)
print(f"Given sequence: '{ip_text}', predicted next word: '{next_word1}'")
# Out:
# enter textam a good
# probability of  girl is  0.058823529411764705
# Given sequence: 'am a good', predicted next word: 'girl'

# %% [markdown]
# **NEXT WORD PREDICTION USING BIGRAM COUNTS WITH ADD K SMOOTHNENING**

# %%
def predict_next_word_bigram_K(word_sequence, bigram_counts, unigram_counts, K): #K=0.5-0.01
    words_in_sequence = word_sequence.lower().split()
    if not words_in_sequence:
        return "Please provide a word sequence."
    last_word = words_in_sequence[-1]
    potential_next_words = {}
    for (w1, w2), count in bigram_counts.items():
        if w1 == last_word:
            potential_next_words[w2] = count

    if not potential_next_words:
        return f"No bigram found starting with '{last_word}'."
    last_word_unigram_count = unigram_counts.get(last_word, 0)
    if last_word_unigram_count == 0:
        return f"'{last_word}' not found in unigram counts. Cannot predict next word."

    predicted_word = None
    max_probability = -1

    for next_word, bigram_count in potential_next_words.items():
        probability = (bigram_count+K) / (last_word_unigram_count+K*V)
        print("probability of " f'{next_word}' " is ", probability)
        if probability > max_probability:
            max_probability = probability
            predicted_word = next_word

    return predicted_word

sequence1 = "I Like"
next_word1 = predict_next_word_bigram_K(sequence1, bigram_counts, unigram_counts,0.5)
print(f"Given sequence: '{sequence1}', predicted next word: '{next_word1}'")

sequence2 = "I am"
next_word2 = predict_next_word_bigram_K(sequence2, bigram_counts, unigram_counts,0.5)
print(f"Given sequence: '{sequence2}', predicted next word: '{next_word2}'")

sequence3 = "playing badminton"
next_word3 = predict_next_word_bigram_K(sequence3, bigram_counts, unigram_counts,0.5)
print(f"Given sequence: '{sequence3}', predicted next word: '{next_word3}'")

sequence4 = "learing i"
next_word4 = predict_next_word_bigram_K(sequence4, bigram_counts, unigram_counts,0.5)
print(f"Given sequence: '{sequence4}', predicted next word: '{next_word4}'")
# Out:
# probability of machine is  0.06976744186046512
# probability of deep is  0.06976744186046512
# probability of playing is  0.11627906976744186
# probability of watching is  0.06976744186046512
# Given sequence: 'I Like', predicted next word: 'playing'
# probability of studying is  0.07692307692307693
# probability of learning is  0.07692307692307693
# probability of a is  0.07692307692307693
# Given sequence: 'I am', predicted next word: 'studying'
# probability of i is  0.08571428571428572
# Given sequence: 'playing badminton', predicted next word: 'i'
# probability of like is  0.20754716981132076
# probability of am is  0.1320754716981132
# probability of completed is  0.05660377358490566
# probability of want is  0.05660377358490566
# Given sequence: 'learing i', predicted next word: 'like'

# %% [markdown]
# # **Deployment of Add-K Smoothening based Bi-Gram Model**

# %%
ip_text=input("enter text")
next_word1 = predict_next_word_bigram_K(ip_text, bigram_counts, unigram_counts,0.5)
print(f"Given sequence: '{ip_text}', predicted next word: '{next_word1}'")
# Out:
# enter textI am
# probability of studying is  0.07692307692307693
# probability of learning is  0.07692307692307693
# probability of a is  0.07692307692307693
# Given sequence: 'I am', predicted next word: 'studying'

# %% [markdown]
# # **Next Word Prediction Using Tri-Gram Counts with Add - K Smoothening**

# %%
def predict_next_word_trigram_K(word_sequence, Trigrams_counts, bigram_counts,K): #K=0.5-0.01

    words_in_sequence = word_sequence.lower().split()
    if not words_in_sequence:
        return "Please provide a word sequence."

    if len(words_in_sequence) < 2:
        return "Sequence must contain at least two words for trigram prediction."

    last_two_words_tuple = tuple(words_in_sequence[-2:])

    potential_next_words = {}
    for (w1, w2, w3), count in Trigrams_counts.items():
        if (w1, w2) == last_two_words_tuple:
            potential_next_words[w3] = count

    if not potential_next_words:
        return f"No trigram found starting with '{' '.join(last_two_words_tuple)}'."
    last_two_words_bigram_count = bigram_counts.get(last_two_words_tuple, 0)
    if last_two_words_bigram_count == 0:
        return f"'{' '.join(last_two_words_tuple)}' not found as a bigram. Cannot predict next word."

    predicted_word = None
    max_probability = -1

    for next_word, trigram_count in potential_next_words.items():
        probability = (trigram_count+K) / (last_two_words_bigram_count+K*V)
        print("probability of  " f'{next_word}' " is ", probability)
        if probability > max_probability:
            max_probability = probability
            predicted_word = next_word

    return predicted_word
sequence1 = "learing i like"
next_word1 = predict_next_word_trigram_K(sequence1, Trigrams_counts, bigram_counts,0.5)
print(f"Given sequence: '{sequence1}', predicted next word: '{next_word1}'")

sequence2 = "am a good"
next_word2 = predict_next_word_trigram_K(sequence2, Trigrams_counts, bigram_counts,0.5)
print(f"Given sequence: '{sequence2}', predicted next word: '{next_word2}'")
# Out:
# probability of  machine is  0.06976744186046512
# probability of  deep is  0.06976744186046512
# probability of  playing is  0.11627906976744186
# probability of  watching is  0.06976744186046512
# Given sequence: 'learing i like', predicted next word: 'playing'
# probability of  girl is  0.08571428571428572
# Given sequence: 'am a good', predicted next word: 'girl'

# %% [markdown]
# # **Deployment of Add-K Smoothening based Tri-Gram Model**

# %%
ip_text=input("enter text")
next_word1 = predict_next_word_trigram_K(ip_text, Trigrams_counts, bigram_counts,0.5)
print(f"Given sequence: '{ip_text}', predicted next word: '{next_word1}'")
# Out:
# enter textlearning i like
# probability of  machine is  0.06976744186046512
# probability of  deep is  0.06976744186046512
# probability of  playing is  0.11627906976744186
# probability of  watching is  0.06976744186046512
# Given sequence: 'learning i like', predicted next word: 'playing'
